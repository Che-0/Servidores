# %% [markdown]
# Pa empezar tenemos que instalar con apt install apache2 o dnf install httpd

# %%
sudo apt install apache2

# %%
sudo dnf install httpd

# %% [markdown]
# Para comprobar que el paquete este instalado y en nuestras librerias:

# %%
apt list apache2

# %% [markdown]
# ## En donde encontramos los archivos de configuracion ? ##
# En donde siempre, vamos a la carpeta etc y ahi buscamos apache2.
#
# /etc/apache2
#
# Aqui vamos a tener diferentes directorios, para configurar las paginas y para las configuraciones del proceso, lo explicare mas adelante.
# pero se ve asi
#
#
# ![image.png](attachment:0e867ad1-ff37-4f9a-ac15-9ee51b963b1d.png)
#
#
# Bueno, explicare algunos de manera resuminada ahora:
#
# Bueno, explicare algunos, pero le puedes decir a grok que te explique de que va cada archivo y claro tambien los tienes que ver y modificar para probar

# %% [markdown]
# Entonces, ya tenemos instalado apache. Podemos verlo tambien con el famoso systemctl o con service.

# %%
    sudo systemctl status apache2

# %%
sudo service apache2 status

# %% [markdown]
# ![image.png](attachment:4690fffd-1e1f-4b89-885f-08d06d76f737.png)
#
# Esto tiene que ver con los procesos, asi que una repasada no estaria mal. En general se pueden parar, resetear, iniciar ...

# %% [markdown]
# Ahora inicializamos el proceso
# ![image.png](attachment:2098f7b1-9352-401f-a063-3cb1475f7fc5.png)

# %% [markdown]
# Si revisaste los archivos de configuracion, entonces viste los sitios quetenia por defecto y el puerto en el que corria
# Pero tambien puedes tirar un:

# %%
sudo apachectl -S

# %% [markdown]
# ![image.png](attachment:e0797bf1-1119-48dd-8dad-23e91ee5f9ac.png)
#
#
# Entonces, vamos al localhost en el puerto 80
#
# http://localhost:80
# o 127.0.0.1:80
#
#
# ![image.png](attachment:d6b36953-ae90-4408-b0ee-9afe7225e0b6.png)
#
# Este dice uwu porque ya habia modificado el archivo
