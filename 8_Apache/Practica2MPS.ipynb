# %% [markdown]
# La primeeeeeeeera vez que hice esto me dio un error.
# Hice todo correcto pero algo al intentar cambiar el mpm fallo y pues se murio jaja
# Asi que mejor practicar en una VM

# %% [markdown]
# Para este ejemplo vamos a empezar inicializando apache

# %%
sudo service apache2 start

# %% [markdown]
# despues un apachectl -S para ver la configuracion
# y un apachectl -V para ver la informacion del servidor
#
# ![image.png](attachment:0ed0191f-2857-4c1c-8c45-f73ed572a440.png)
#
#
# ![image.png](attachment:127471b2-5b6e-4039-9c0f-c9c3f83e6798.png)

# %% [markdown]
# Como se puede ver en la imagen, el MPM esta configurado en event.

# %% [markdown]
# ## Que podemos hacer para cambiarlo??
# 1- deshabilitar el modulo event

# %%
sudo a2dismod mpm_event

# %% [markdown]
# ![image.png](attachment:e61a566f-815f-422e-9bb9-6c2239d7bf6b.png)
#
# NO podemos reiniciar porque pues no hemos puesto otro mpm
#
# ![image.png](attachment:1e78b51f-8e27-4e28-a2d4-1b7aafc314cb.png)

# %% [markdown]
# Ahora tenemos que activar prefork o worker

# %%
sudo a2enmod mpm_prefork

# %% [markdown]
# ![image.png](attachment:3c946060-e8a5-4d8c-b570-273d7705bce9.png)
#
# Y listo, cambiamos de mpm
#
# ![image.png](attachment:383ad0d4-145c-4300-b3fe-87ba5f5547e0.png)

# %% [markdown]
# Otra cosa, si vamos al directorio de modulos diponibles, nos apareceran tooooooodos, hasta los que acabamos de usar
# ![image.png](attachment:e39b821e-00a9-4dca-8855-b97e6f5abe6f.png)
